# %%
import numpy as np
import pandas as pd

# %%
import os

# %%
os.listdir()
# Out:
# ['ForceDirectOnly.txt',
#  'Model.txt',
#  '.DS_Store',
#  'Untitled.ipynb',
#  'ForceDirectOnly',
#  'output_force.txt',
#  'output_force_only.txt',
#  'ForceDirect.txt',
#  'Model',
#  '.ipynb_checkpoints',
#  'output_model.txt',
#  'ForceDirect']

# %%
model.mean() - force.mean()
# Out:
# id          0.000000
# size        0.000000
# density     0.000000
# cross      -0.730000
# angleM      0.396275
# angleD      0.315135
# minAng     -0.583972
# edgeM       0.002253
# edgeD      -0.001234
# minVertx    0.059154
# finVertx   -0.087675
# devVertx   -0.569254
# minPtEdg    0.000162
# dtype: float64

# %%
force = pd.read_csv ('ForceDirect.txt', sep = ' ', header = 1)
force.head(5)
# Out:
#    id  size  density  cross     angleM     angleD    minAng     edgeM  \
# 0   1    35     44.0    178  52.782186  23.575698  2.189695  0.719561
# 1   2    46     66.0    411  53.415376  21.951599  5.983265  0.714857
# 2   3    38     44.0    166  54.809628  22.855835  5.106531  0.540651
# 3   4    43     48.0    204  50.191070  23.478183  2.840208  0.510974
# 4   5    37     47.0    205  50.197341  22.228956  6.702721  0.517209
#
#       edgeD  minVertx    finVertx    devVertx  minPtEdg
# 0  0.428285  0.101426   95.421084  103.637334  0.000972
# 1  0.417115  0.407046   93.252146  102.779939  0.001024
# 2  0.366246  0.044052  106.633232  111.479667  0.000451
# 3  0.364216  0.100113   90.801404   99.711199  0.000219
# 4  0.306885  0.349061   98.489377  109.815406  0.002305

# %%
model = pd.read_csv ('Model.txt', sep = ' ', header = 1)
model.head(5)
# Out:
#    id  size  density  cross     angleM     angleD    minAng     edgeM  \
# 0   1    35     44.0    178  52.181565  23.107216  4.970416  0.738972
# 1   2    46     66.0    433  53.768707  22.812100  1.119293  0.764854
# 2   3    38     44.0    162  53.259258  22.811760  3.947969  0.537152
# 3   4    43     48.0    229  45.474847  20.676024  1.725616  0.483592
# 4   5    37     47.0    147  54.656171  23.841915  3.701632  0.510035
#
#       edgeD  minVertx    finVertx    devVertx  minPtEdg
# 0  0.438044  0.022024   94.301220  101.185124  0.000395
# 1  0.429865  0.508632   94.105438  103.396098  0.000291
# 2  0.355020  0.167032  105.957942  110.931765  0.000428
# 3  0.372307  0.755085   91.297152   98.137858  0.001362
# 4  0.303808  0.000258  103.031356  113.571953  0.000002

# %%
force_only = pd.read_csv ('ForceDirectOnly.txt', sep = ' ', header = 1)
force_only.head(5)
# Out:
#    id  size  density  cross     angleM     angleD     minAng     edgeM  \
# 0   1    35     44.0      8  56.971357  20.870189  21.588510  0.120698
# 1   2    46     66.0     37  60.627086  20.583404  15.476038  0.279290
# 2   3    38     44.0     12  55.732977  18.498551  14.788353  0.136286
# 3   4    43     48.0      7  69.726613  17.317691  30.058373  0.125815
# 4   5    37     47.0      9  65.773932  15.205290  36.057512  0.183418
#
#       edgeD  minVertx   finVertx   devVertx  minPtEdg
# 0  0.035318  2.431403  47.181701  41.155183  0.004133
# 1  0.078744  4.497152  57.244731  51.996300  0.000734
# 2  0.038627  3.607053  58.221427  51.309012  0.004113
# 3  0.035795  0.935545  47.339345  38.410456  0.001441
# 4  0.051268  3.488409  52.808223  44.988578  0.000268
